# %%
# !pip install --no-index /kaggle/input/datasets/kurshidbasheer/biopython-offline/biopython-1.83-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Out:
# Processing /kaggle/input/datasets/kurshidbasheer/biopython-offline/biopython-1.83-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from biopython==1.83) (2.0.2)
# Installing collected packages: biopython
# Successfully installed biopython-1.83

# %%
# !pip install --no-index /kaggle/input/datasets/kurshidbasheer/pyg-2-7-torch-2-9-cpu-py312-kur/torch_geometric-2.7.0-py3-none-any.whl
# Out:
# Processing /kaggle/input/datasets/kurshidbasheer/pyg-2-7-torch-2-9-cpu-py312-kur/torch_geometric-2.7.0-py3-none-any.whl
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.7.0) (3.13.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.7.0) (2025.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.7.0) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.7.0) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.7.0) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.7.0) (3.3.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.7.0) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.7.0) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.7.0) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.7.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.7.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.7.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.7.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.7.0) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.7.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.7.0) (1.22.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch-geometric==2.7.0) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric==2.7.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric==2.7.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric==2.7.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric==2.7.0) (2026.1.4)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp->torch-geometric==2.7.0) (4.15.0)
# Installing collected packages: torch-geometric
# Successfully installed torch-geometric-2.7.0

# %% [markdown]
# # Reproducibility

# %%
import torch
import numpy as np
import random

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed(42)

# %% [markdown]
# # Paths

# %%
TRAIN_SEQ = "/kaggle/input/stanford-rna-3d-folding-2/train_sequences.csv"
TRAIN_LBL = "/kaggle/input/stanford-rna-3d-folding-2/train_labels.csv"

VAL_SEQ   = "/kaggle/input/stanford-rna-3d-folding-2/validation_sequences.csv"
VAL_LBL   = "/kaggle/input/stanford-rna-3d-folding-2/validation_labels.csv"

TEST_SEQ  = "/kaggle/input/stanford-rna-3d-folding-2/test_sequences.csv"

MSA_DIR   = "/kaggle/input/stanford-rna-3d-folding-2/MSA"
PDB_DIR   = "/kaggle/input/stanford-rna-3d-folding-2/PDB_RNA"
META_PATH = "/kaggle/input/stanford-rna-3d-folding-2/extra/rna_metadata.csv"

# %% [markdown]
# # Dataset (Train & Validation)

# %%
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset
from Bio.Seq import Seq

NUC_MAP = {'A':0, 'U':1, 'G':2, 'C':3}

def clean_sequence(seq):
    seq_obj = Seq(seq.upper())
    return "".join([n for n in str(seq_obj) if n in NUC_MAP])

def one_hot(seq):
    x = torch.zeros(len(seq), 4)
    for i, s in enumerate(seq):
        x[i, NUC_MAP[s]] = 1
    return x


class RNADataset(Dataset):

    def __init__(self, seq_csv, label_csv=None, max_length=1000):

        self.q_df = pd.read_csv(seq_csv)
        self.max_length = max_length
        self.has_labels = label_csv is not None

        if self.has_labels:
            labels = pd.read_csv(label_csv, low_memory=False)

            labels["struct_id"] = labels["ID"].str.split("_").str[0]
            labels["res_idx"]   = labels["ID"].str.split("_").str[1].astype(int)

            self.structures = {}

            for k, g in labels.groupby("struct_id"):

                g = g.sort_values("res_idx")

                coords = g[["x_1", "y_1", "z_1"]].values.astype(np.float32)
                coords = torch.from_numpy(coords)

                # Remove residues with NaNs
                valid_mask = ~torch.isnan(coords).any(dim=1)
                cleaned_coords = coords[valid_mask]

                if valid_mask.sum() != len(valid_mask):
                    print(f"Removed NaN residues in structure {k}")

                # Drop structure if completely corrupted
                if cleaned_coords.shape[0] > 0:
                    self.structures[k] = cleaned_coords
                else:
                    print(f"Dropped fully corrupted structure {k}")

            self.valid_ids = [
                sid for sid in self.q_df["target_id"]
                if sid in self.structures
            ]

        else:
            self.valid_ids = list(self.q_df["target_id"])

    def __len__(self):
        return len(self.valid_ids)

    def __getitem__(self, idx):

        sid = self.valid_ids[idx]
        row = self.q_df[self.q_df["target_id"] == sid].iloc[0]

        seq = clean_sequence(row["sequence"])

        if self.has_labels:

            coords = self.structures[sid]

            L = min(len(seq), coords.shape[0])
            seq = seq[:L]
            coords = coords[:L]

            # 🔹 Center coordinates (remove translation)
            coords = coords - coords.mean(dim=0, keepdim=True)

            # 🔹 Normalize scale (stabilize training)
            coords = coords / (coords.std() + 1e-8)

            # Final safety check
            if torch.isnan(coords).any():
                raise ValueError(f"NaNs detected after normalization in {sid}")

        else:
            coords = None
            L = len(seq)

        if L > self.max_length:
            seq = seq[:self.max_length]
            if coords is not None:
                coords = coords[:self.max_length]

        x = one_hot(seq)

        # Positional feature
        pos_feat = torch.arange(len(seq)).float().unsqueeze(-1) / len(seq)
        x = torch.cat([x, pos_feat], dim=1)

        return sid, x, coords

# %%
dataset = RNADataset(TRAIN_SEQ, TRAIN_LBL)

print("Dataset size:", len(dataset))
# Out:
# Removed NaN residues in structure 1AQ3
# Removed NaN residues in structure 1AQ4
# Removed NaN residues in structure 1E7K
# Removed NaN residues in structure 1EUY
# Removed NaN residues in structure 1FFK
# Removed NaN residues in structure 1FJG
# Removed NaN residues in structure 1FKA
# Removed NaN residues in structure 1FOQ
# Removed NaN residues in structure 1G1X
# Removed NaN residues in structure 1H3E
# Removed NaN residues in structure 1H4Q
# Removed NaN residues in structure 1H4S
# Removed NaN residues in structure 1HNW
# Removed NaN residues in structure 1HNX
# Removed NaN residues in structure 1HNZ
# Removed NaN residues in structure 1HR0
# Removed NaN residues in structure 1HR2
# Removed NaN residues in structure 1IBK
# Removed NaN residues in structure 1IBL
# Removed NaN residues in structure 1IBM
# Removed NaN residues in structure 1J1U
# Removed NaN residues in structure 1J2B
# Removed NaN residues in structure 1J5A
# Removed NaN residues in structure 1J5E
# Removed NaN residues in structure 1J7T
# Removed NaN residues in structure 1JGO
# Removed NaN residues in structure 1JGP
# Removed NaN residues in structure 1JGQ
# Removed NaN residues in structure 1JJ2
# Removed NaN residues in structure 1JU7
# Removed NaN residues in structure 1JWC
# Removed NaN residues in structure 1JZX
# Removed NaN residues in structure 1JZY
# Removed NaN residues in structure 1JZZ
# Removed NaN residues in structure 1K01
# Removed NaN residues in structure 1K73
# Removed NaN residues in structure 1K8A
# Removed NaN residues in structure 1K9M
# Removed NaN residues in structure 1KC8
# Removed NaN residues in structure 1KD1
# Removed NaN residues in structure 1KH6
# Removed NaN residues in structure 1KPY
# Removed NaN residues in structure 1KPZ
# Removed NaN residues in structure 1KQS
# Removed NaN residues in structure 1L9A
# Removed NaN residues in structure 1LC4
# Removed NaN residues in structure 1M1K
# Removed NaN residues in structure 1M8V
# Removed NaN residues in structure 1M90
# Removed NaN residues in structure 1MJ1
# Removed NaN residues in structure 1ML5
# Removed NaN residues in structure 1MWL
# Removed NaN residues in structure 1N32
# Removed NaN residues in structure 1N33
# Removed NaN residues in structure 1N34
# Removed NaN residues in structure 9LRI
# Removed NaN residues in structure 9M78
# Removed NaN residues in structure 9M79
# Removed NaN residues in structure 9MCW
# Removed NaN residues in structure 9MEE
# Removed NaN residues in structure 9MM6
# Removed NaN residues in structure 9MMG
# Removed NaN residues in structure 9MOR
# Removed NaN residues in structure 9MQS
# Removed NaN residues in structure 9MQT
# Removed NaN residues in structure 9MQU
# Removed NaN residues in structure 9MR4
# Removed NaN residues in structure 9MTQ
# Removed NaN residues in structure 9MTT
# Removed NaN residues in structure 9MUJ
# Removed NaN residues in structure 9MX3
# Removed NaN residues in structure 9N6V
# Removed NaN residues in structure 9N6W
# Removed NaN residues in structure 9N6X
# Removed NaN residues in structure 9N6Y
# Removed NaN residues in structure 9N9J
# Removed NaN residues in structure 9NHB
# Removed NaN residues in structure 9NHC
# Removed NaN residues in structure 9NHS
# Removed NaN residues in structure 9NRI
# Removed NaN residues in structure 9NTA
# Removed NaN residues in structure 9NVU
# Removed NaN residues in structure 9O17
# Removed NaN residues in structure 9O3H
# Removed NaN residues in structure 9O3I
# Removed NaN residues in structure 9O3J
# Removed NaN residues in structure 9O3L
# Removed NaN residues in structure 9OFV
# Removed NaN residues in structure 9OU7
# Removed NaN residues in structure 9P38
# Removed NaN residues in structure 9P4I
# Removed NaN residues in structure 9PYW
# Removed NaN residues in structure 9PYZ
# Removed NaN residues in structure 9PZ0
# Removed NaN residues in structure 9PZG
# Removed NaN residues in structure 9Q87
# Removed NaN residues in structure 9QAX
# Removed NaN residues in structure 9QAY
# Removed NaN residues in structure 9QAZ
# Removed NaN residues in structure 9QEG
# Removed NaN residues in structure 9QIW
# Removed NaN residues in structure 9QRP
# Removed NaN residues in structure 9QT5
# Removed NaN residues in structure 9SDF
# Removed NaN residues in structure 9SFB
# Removed NaN residues in structure 9U47
# Removed NaN residues in structure 9UA2
# Removed NaN residues in structure 9UWH
# Removed NaN residues in structure 9V1I
# Removed NaN residues in structure 9V1J
# Removed NaN residues in structure 9V21
# Removed NaN residues in structure 9V24
# Removed NaN residues in structure 9V26
# Removed NaN residues in structure 9V27
# Removed NaN residues in structure 9VKU
# Removed NaN residues in structure 9VMA
# Removed NaN residues in structure 9WNQ
# Removed NaN residues in structure 9WNR
# Removed NaN residues in structure 9ZBQ
# Removed NaN residues in structure 9ZC6
# Dataset size: 5716

# %% [markdown]
# Check First Sample

# %%
sid, x, coords = dataset[0]

print("SID:", sid)
print("x shape:", x.shape)
print("coords shape:", coords.shape)
# Out:
# SID: 4TNA
# x shape: torch.Size([76, 5])
# coords shape: torch.Size([76, 3])

# %% [markdown]
# Check Alignment Integrity

# %%
for i in range(5):
    sid, x, coords = dataset[i]
    print(f"{sid} | x:{x.shape} | coords:{coords.shape}")
    assert x.shape[0] == coords.shape[0]
# Out:
# 4TNA | x:torch.Size([76, 5]) | coords:torch.Size([76, 3])
# 6TNA | x:torch.Size([76, 5]) | coords:torch.Size([76, 3])
# 1TRA | x:torch.Size([76, 5]) | coords:torch.Size([76, 3])
# 1TN2 | x:torch.Size([76, 5]) | coords:torch.Size([76, 3])
# 1TN1 | x:torch.Size([76, 5]) | coords:torch.Size([76, 3])

# %% [markdown]
# Alignment correspondence check

# %%
rows = []

for i in range(10):
    sid_dataset, _, _ = dataset[i]
    
    # since you filtered valid_ids, this is safer:
    sid_from_valid_list = dataset.valid_ids[i]
    
    rows.append({
        "Index": i,
        "ID_from_valid_ids": sid_from_valid_list,
        "ID_from_dataset": sid_dataset,
        "Match": sid_from_valid_list == sid_dataset
    })

alignment_df = pd.DataFrame(rows)
alignment_df
# Out:
#    Index ID_from_valid_ids ID_from_dataset  Match
# 0      0              4TNA            4TNA   True
# 1      1              6TNA            6TNA   True
# 2      2              1TRA            1TRA   True
# 3      3              1TN2            1TN2   True
# 4      4              1TN1            1TN1   True
# 5      5              2TRA            2TRA   True
# 6      6              3TRA            3TRA   True
# 7      7              4TRA            4TRA   True
# 8      8              1RNA            1RNA   True
# 9      9              1ELH            1ELH   True

# %% [markdown]
# Check id alignment correspondence

# %%
seq_df = pd.read_csv(TRAIN_SEQ)
lbl_df = pd.read_csv(TRAIN_LBL, low_memory=False)

lbl_df["struct_id"] = lbl_df["ID"].str.split("_").str[0]

seq_ids = set(seq_df["target_id"])
label_ids = set(lbl_df["struct_id"])

print("IDs in sequences:", len(seq_ids))
print("IDs in labels:", len(label_ids))
print("Common IDs:", len(seq_ids & label_ids))
print("Missing in labels:", len(seq_ids - label_ids))
# Out:
# IDs in sequences: 5716
# IDs in labels: 5716
# Common IDs: 5716
# Missing in labels: 0

# %% [markdown]
# Check Sequence Cleaning Actually Works

# %%
sid, x, coords = dataset[0]

one_hot_part = x[:, :4]
sum_per_row = one_hot_part.sum(dim=1)

print("Min row sum:", sum_per_row.min().item())
print("Max row sum:", sum_per_row.max().item())
# Out:
# Min row sum: 1.0
# Max row sum: 1.0

# %% [markdown]
# Check Position Feature Range

# %%
pos_feature = x[:, 4]

print("Min pos:", pos_feature.min().item())
print("Max pos:", pos_feature.max().item())
# Out:
# Min pos: 0.0
# Max pos: 0.9868420958518982

# %% [markdown]
# Check Coordinate Order Correct

# %%
import pandas as pd

labels = pd.read_csv(TRAIN_LBL, low_memory=False)
tmp = labels[labels["ID"].str.startswith(sid + "_")]

print(tmp["ID"].head())
# Out:
# 774838    4TNA_1
# 774839    4TNA_2
# 774840    4TNA_3
# 774841    4TNA_4
# 774842    4TNA_5
# Name: ID, dtype: object

# %% [markdown]
# Check Max Length Cropping Works

# %%
small_dataset = RNADataset(TRAIN_SEQ, TRAIN_LBL, max_length=50)

sid, x, coords = small_dataset[0]
print("Length after crop:", x.shape[0])
# Out:
# Removed NaN residues in structure 1AQ3
# Removed NaN residues in structure 1AQ4
# Removed NaN residues in structure 1E7K
# Removed NaN residues in structure 1EUY
# Removed NaN residues in structure 1FFK
# Removed NaN residues in structure 1FJG
# Removed NaN residues in structure 1FKA
# Removed NaN residues in structure 1FOQ
# Removed NaN residues in structure 1G1X
# Removed NaN residues in structure 1H3E
# Removed NaN residues in structure 9Q87
# Removed NaN residues in structure 9QAX
# Removed NaN residues in structure 9QAY
# Removed NaN residues in structure 9QAZ
# Removed NaN residues in structure 9QEG
# Removed NaN residues in structure 9QIW
# Removed NaN residues in structure 9QRP
# Removed NaN residues in structure 9QT5
# Removed NaN residues in structure 9SDF
# Removed NaN residues in structure 9SFB
# Removed NaN residues in structure 9U47
# Removed NaN residues in structure 9UA2
# Removed NaN residues in structure 9UWH
# Removed NaN residues in structure 9V1I
# Removed NaN residues in structure 9V1J
# Removed NaN residues in structure 9V21
# Removed NaN residues in structure 9V24
# Removed NaN residues in structure 9V26
# Removed NaN residues in structure 9V27
# Removed NaN residues in structure 9VKU
# Removed NaN residues in structure 9VMA
# Removed NaN residues in structure 9WNQ
# Removed NaN residues in structure 9WNR
# Removed NaN residues in structure 9ZBQ
# Removed NaN residues in structure 9ZC6
# Length after crop: 50

# %% [markdown]
# Check That All Target IDs Have Structures

# %%
all_ids = set(dataset.q_df["target_id"])
valid_ids = set(dataset.valid_ids)

print("Missing IDs:", len(all_ids - valid_ids))
# Out:
# Missing IDs: 0

# %% [markdown]
# Structural Check

# %%
for i in range(20):
    sid, x, coords = dataset[i]
    if x.shape[0] != coords.shape[0]:
        print("Mismatch found:", sid)

# nothing prints = alignment stable

# %% [markdown]
# # Graph Builder

# %%
from torch_geometric.data import Data

def center_coordinates(coords):
    center = coords.mean(dim=0, keepdim=True)
    return coords - center

def build_graph(x, coords=None, k=2):

    L = x.size(0)

    edge_index = []
    edge_attr  = []

    if coords is not None:
        coords = center_coordinates(coords)

    for i in range(L):
        for j in range(max(0, i-k), min(L, i+k+1)):
            if i == j:
                continue

            edge_index.append([i, j])

            if coords is not None:
                dist = torch.norm(coords[i] - coords[j])
                edge_attr.append([dist.item()])
            else:
                edge_attr.append([abs(i-j)])

    edge_index = torch.tensor(edge_index, dtype=torch.long).t().contiguous()
    edge_attr  = torch.tensor(edge_attr, dtype=torch.float)

    data = Data(
        x=x,
        edge_index=edge_index,
        edge_attr=edge_attr
    )

    if coords is not None:
        data.pos = coords
        data.y   = coords

    return data

# %% [markdown]
# Basic Graph Build Test

# %%
sid, x, coords = dataset[0]

graph = build_graph(x, coords, k=2)

print("Nodes:", graph.num_nodes)
print("Edges:", graph.num_edges)
print("Node feature shape:", graph.x.shape)
print("Edge index shape:", graph.edge_index.shape)
print("Edge attr shape:", graph.edge_attr.shape)
print("Pos shape:", graph.pos.shape)
# Out:
# Nodes: 76
# Edges: 298
# Node feature shape: torch.Size([76, 5])
# Edge index shape: torch.Size([2, 298])
# Edge attr shape: torch.Size([298, 1])
# Pos shape: torch.Size([76, 3])

# %% [markdown]
# Check Edge Count Logic
#
# For k=2, each node connects to up to 4 neighbors (except boundaries).
#
# Expected edges (approx):
#
# 𝐸 ≈𝐿×2𝑘

# %%
L = graph.num_nodes
print("Expected approx edges:", L * 4)
print("Actual edges:", graph.num_edges)
# Out:
# Expected approx edges: 304
# Actual edges: 298

# %% [markdown]
# NaNs

# %%
print("NaN in x:", torch.isnan(graph.x).any().item())
print("NaN in pos:", torch.isnan(graph.pos).any().item())
print("NaN in edge_attr:", torch.isnan(graph.edge_attr).any().item())
# Out:
# NaN in x: False
# NaN in pos: False
# NaN in edge_attr: False

# %% [markdown]
# Verify Centering

# %%
print("Coordinate mean:", graph.pos.mean(dim=0))
# not failed (checked)
# Out:
# Coordinate mean: tensor([-2.4595e-06, -1.6313e-07,  2.5097e-06])

# %% [markdown]
# # Build Train / Validation Graphs

# %%
train_dataset = RNADataset(TRAIN_SEQ, TRAIN_LBL)
val_dataset   = RNADataset(VAL_SEQ, VAL_LBL)
test_dataset  = RNADataset(TEST_SEQ, None)

train_graphs = []
val_graphs   = []

for sid, x, coords in train_dataset:
    train_graphs.append(build_graph(x, coords))

for sid, x, coords in val_dataset:
    val_graphs.append(build_graph(x, coords))
# Out:
# Removed NaN residues in structure 1AQ3
# Removed NaN residues in structure 1AQ4
# Removed NaN residues in structure 1E7K
# Removed NaN residues in structure 1EUY
# Removed NaN residues in structure 1FFK
# Removed NaN residues in structure 1FJG
# Removed NaN residues in structure 1FKA
# Removed NaN residues in structure 1FOQ
# Removed NaN residues in structure 1G1X
# Removed NaN residues in structure 1H3E
# Removed NaN residues in structure 1H4Q
# Removed NaN residues in structure 1H4S
# Removed NaN residues in structure 1HNW
# Removed NaN residues in structure 1HNX
# Removed NaN residues in structure 1HNZ
# Removed NaN residues in structure 1HR0
# Removed NaN residues in structure 1HR2
# Removed NaN residues in structure 1IBK
# Removed NaN residues in structure 1IBL
# Removed NaN residues in structure 1IBM
# Removed NaN residues in structure 1J1U
# Removed NaN residues in structure 1J2B
# Removed NaN residues in structure 1J5A
# Removed NaN residues in structure 1J5E
# Removed NaN residues in structure 1J7T
# Removed NaN residues in structure 1JGO
# Removed NaN residues in structure 1JGP
# Removed NaN residues in structure 1JGQ
# Removed NaN residues in structure 1JJ2
# Removed NaN residues in structure 1JU7
# Removed NaN residues in structure 1JWC
# Removed NaN residues in structure 1JZX
# Removed NaN residues in structure 1JZY
# Removed NaN residues in structure 1JZZ
# Removed NaN residues in structure 1K01
# Removed NaN residues in structure 1K73
# Removed NaN residues in structure 1K8A
# Removed NaN residues in structure 1K9M
# Removed NaN residues in structure 1KC8
# Removed NaN residues in structure 1KD1
# Removed NaN residues in structure 1KH6
# Removed NaN residues in structure 1KPY
# Removed NaN residues in structure 1KPZ
# Removed NaN residues in structure 1KQS
# Removed NaN residues in structure 1L9A
# Removed NaN residues in structure 1LC4
# Removed NaN residues in structure 1M1K
# Removed NaN residues in structure 1M8V
# Removed NaN residues in structure 1M90
# Removed NaN residues in structure 1MJ1
# Removed NaN residues in structure 1ML5
# Removed NaN residues in structure 1MWL
# Removed NaN residues in structure 1N32
# Removed NaN residues in structure 1N33
# Removed NaN residues in structure 1N34
# Removed NaN residues in structure 1N35
# Removed NaN residues in structure 1N36
# Removed NaN residues in structure 1N8R
# Removed NaN residues in structure 1NBS
# Removed NaN residues in structure 1NJI
# Removed NaN residues in structure 1NJM
# Removed NaN residues in structure 9MM6
# Removed NaN residues in structure 9MMG
# Removed NaN residues in structure 9MOR
# Removed NaN residues in structure 9MQS
# Removed NaN residues in structure 9MQT
# Removed NaN residues in structure 9MQU
# Removed NaN residues in structure 9MR4
# Removed NaN residues in structure 9MTQ
# Removed NaN residues in structure 9MTT
# Removed NaN residues in structure 9MUJ
# Removed NaN residues in structure 9MX3
# Removed NaN residues in structure 9N6V
# Removed NaN residues in structure 9N6W
# Removed NaN residues in structure 9N6X
# Removed NaN residues in structure 9N6Y
# Removed NaN residues in structure 9N9J
# Removed NaN residues in structure 9NHB
# Removed NaN residues in structure 9NHC
# Removed NaN residues in structure 9NHS
# Removed NaN residues in structure 9NRI
# Removed NaN residues in structure 9NTA
# Removed NaN residues in structure 9NVU
# Removed NaN residues in structure 9O17
# Removed NaN residues in structure 9O3H
# Removed NaN residues in structure 9O3I
# Removed NaN residues in structure 9O3J
# Removed NaN residues in structure 9O3L
# Removed NaN residues in structure 9OFV
# Removed NaN residues in structure 9OU7
# Removed NaN residues in structure 9P38
# Removed NaN residues in structure 9P4I
# Removed NaN residues in structure 9PYW
# Removed NaN residues in structure 9PYZ
# Removed NaN residues in structure 9PZ0
# Removed NaN residues in structure 9PZG
# Removed NaN residues in structure 9Q87
# Removed NaN residues in structure 9QAX
# Removed NaN residues in structure 9QAY
# Removed NaN residues in structure 9QAZ
# Removed NaN residues in structure 9QEG
# Removed NaN residues in structure 9QIW
# Removed NaN residues in structure 9QRP
# Removed NaN residues in structure 9QT5
# Removed NaN residues in structure 9SDF
# Removed NaN residues in structure 9SFB
# Removed NaN residues in structure 9U47
# Removed NaN residues in structure 9UA2
# Removed NaN residues in structure 9UWH
# Removed NaN residues in structure 9V1I
# Removed NaN residues in structure 9V1J
# Removed NaN residues in structure 9V21
# Removed NaN residues in structure 9V24
# Removed NaN residues in structure 9V26
# Removed NaN residues in structure 9V27
# Removed NaN residues in structure 9VKU
# Removed NaN residues in structure 9VMA
# Removed NaN residues in structure 9WNQ
# Removed NaN residues in structure 9WNR
# Removed NaN residues in structure 9ZBQ
# Removed NaN residues in structure 9ZC6

# %% [markdown]
# Graph integrity validation

# %%
for i, g in enumerate(train_graphs):
    assert not torch.isnan(g.pos).any(), f"NaNs in train graph {i}"
    assert not torch.isnan(g.x).any(), f"NaNs in node features {i}"
    assert not torch.isnan(g.edge_attr).any(), f"NaNs in edge_attr {i}"

for i, g in enumerate(val_graphs):
    assert not torch.isnan(g.pos).any(), f"NaNs in val graph {i}"
    assert not torch.isnan(g.x).any(), f"NaNs in node features {i}"
    assert not torch.isnan(g.edge_attr).any(), f"NaNs in edge_attr {i}"

print("All graphs structurally clean.")
# Out:
# All graphs structurally clean.

# %% [markdown]
# Confirm Graph Counts Match Dataset

# %%
print("Train graphs:", len(train_graphs))
print("Train dataset:", len(train_dataset))

print("Val graphs:", len(val_graphs))
print("Val dataset:", len(val_dataset))
# Out:
# Train graphs: 5716
# Train dataset: 5716
# Val graphs: 28
# Val dataset: 28

# %% [markdown]
# Inspect One Graph Deeply

# %%
g = train_graphs[0]

print("Nodes:", g.num_nodes)
print("Edges:", g.num_edges)
print("x shape:", g.x.shape)
print("pos shape:", g.pos.shape)
print("y shape:", g.y.shape)
print("edge_attr shape:", g.edge_attr.shape)
# Out:
# Nodes: 76
# Edges: 298
# x shape: torch.Size([76, 5])
# pos shape: torch.Size([76, 3])
# y shape: torch.Size([76, 3])
# edge_attr shape: torch.Size([298, 1])

# %% [markdown]
# Check For Corruption Across Entire Train Set

# %%
for i, g in enumerate(train_graphs[:50]):
    assert g.x.shape[0] == g.pos.shape[0]
    assert g.pos.shape[0] == g.y.shape[0]
    assert g.edge_index.shape[1] == g.edge_attr.shape[0]
    assert not torch.isnan(g.x).any()
    assert not torch.isnan(g.pos).any()
    assert not torch.isnan(g.edge_attr).any()

print("Graphs structurally stable")
# Out:
# Graphs structurally stable

# %% [markdown]
# **---------------------------------------------------------------------------**

# %% [markdown]
# # Debugging Structures
#
# In the Stanford RNA dataset:
#
# Some residues are partially resolved
#
# Some coordinates are missing in CIF parsing
#
# CSV may contain blank numeric fields
#
# When you convert to float → they become NaN.

# %% [markdown]
# Identify which graph is curropt

# %%
found = False

for i, g in enumerate(train_graphs):
    if torch.isnan(g.pos).any():
        print(f"NaNs found in graph index: {i}")
        print("Number of NaNs:", torch.isnan(g.pos).sum().item())
        bad_index = i
        found = True
        break

if found:
    bad_sid = train_dataset.valid_ids[bad_index]
    print("Corrupted structure ID:", bad_sid)
else:
    print("No corrupted structures found.")
# Out:
# No corrupted structures found.

# %% [markdown]
# Check Raw Coordinates Before Centering

# %%
sid, x, coords = train_dataset[bad_index]

print("NaN in raw coords:", torch.isnan(coords).any().item())
print("NaN count:", torch.isnan(coords).sum().item())
# Out:
# NaN in raw coords: False
# NaN count: 0

# %% [markdown]
# **---------------------------------------------------------------------------**

# %% [markdown]
# Test Batching

# %%
from torch_geometric.loader import DataLoader

loader = DataLoader(train_graphs, batch_size=4, shuffle=True)

batch = next(iter(loader))

print(batch)
print("Batch nodes:", batch.x.shape)
print("Batch edges:", batch.edge_index.shape)
print("Batch pos:", batch.pos.shape)
# Out:
# DataBatch(x=[1858, 5], edge_index=[2, 7408], edge_attr=[7408, 1], pos=[1858, 3], y=[1858, 3], batch=[1858], ptr=[5])
# Batch nodes: torch.Size([1858, 5])
# Batch edges: torch.Size([2, 7408])
# Batch pos: torch.Size([1858, 3])

# %%
print("Unique graphs in batch:", batch.batch.unique())
# Out:
# Unique graphs in batch: tensor([0, 1, 2, 3])

# %% [markdown]
# Mini Forward Pass Test

# %%
import torch
import torch.nn as nn
from torch_geometric.nn import GCNConv

class TestModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = GCNConv(5, 32)
        self.conv2 = GCNConv(32, 3)

    def forward(self, data):
        x = self.conv1(data.x, data.edge_index)
        x = torch.relu(x)
        x = self.conv2(x, data.edge_index)
        return x

# %%
model = TestModel()

batch = next(iter(loader))
out = model(batch)

print("Output shape:", out.shape)
print("Target shape:", batch.y.shape)
# Out:
# Output shape: torch.Size([164, 3])
# Target shape: torch.Size([164, 3])

# %% [markdown]
# Loss Test

# %%
loss_fn = nn.MSELoss()
loss = loss_fn(out, batch.y)

print("Loss:", loss.item())
# Out:
# Loss: 1.0143502950668335

# %% [markdown]
# Confirm the Coordinate Scale

# %%
print("Target min:", batch.y.min().item())
print("Target max:", batch.y.max().item())
print("Target std:", batch.y.std().item())
# Out:
# Target min: -2.6806697845458984
# Target max: 2.2892274856567383
# Target std: 0.9969403147697449

# %% [markdown]
# # DataLoaders

# %%
from torch_geometric.loader import DataLoader

train_loader = DataLoader(train_graphs, batch_size=8, shuffle=True)
val_loader   = DataLoader(val_graphs, batch_size=8, shuffle=False)

# %% [markdown]
# # EGNN Model

# %%
import torch
import torch.nn as nn


class EGNNLayer(nn.Module):
    def __init__(self, feat_dim):
        super().__init__()

        # Edge message network
        self.edge_mlp = nn.Sequential(
            nn.Linear(2 * feat_dim + 1, feat_dim),
            nn.ReLU(),
            nn.Linear(feat_dim, feat_dim),
            nn.ReLU()
        )

        # Coordinate weight (scalar)
        self.coord_mlp = nn.Sequential(
            nn.Linear(feat_dim, 1),
            nn.Tanh()   # stabilizes coordinate updates
        )

        # Node update network
        self.node_mlp = nn.Sequential(
            nn.Linear(feat_dim, feat_dim),
            nn.ReLU(),
            nn.Linear(feat_dim, feat_dim)
        )

    def forward(self, x, pos, edge_index):

        row, col = edge_index

        # Relative coordinates
        diff = pos[row] - pos[col]
        dist2 = torch.sum(diff ** 2, dim=1, keepdim=True)

        # Edge message
        edge_input = torch.cat([x[row], x[col], dist2], dim=1)
        m_ij = self.edge_mlp(edge_input)

        # ----- Coordinate update -----
        coord_weight = self.coord_mlp(m_ij)
        pos_update = diff * coord_weight

        pos = pos + torch.zeros_like(pos).index_add_(0, row, pos_update)

        # ----- Node feature update -----
        agg = torch.zeros_like(x).index_add_(0, row, m_ij)
        x = x + self.node_mlp(agg)

        return x, pos


class RNAEGNN(nn.Module):
    def __init__(self, in_channels, hidden_dim=128, layers=3):
        super().__init__()

        self.embedding = nn.Linear(in_channels, hidden_dim)

        self.layers = nn.ModuleList([
            EGNNLayer(hidden_dim) for _ in range(layers)
        ])

    def forward(self, data):

        x = self.embedding(data.x)

        # ✅ Only this line changed
        pos = torch.zeros_like(data.pos)

        for layer in self.layers:
            x, pos = layer(x, pos, data.edge_index)

        return pos

# %% [markdown]
# Verify It’s Working

# %%
batch = next(iter(train_loader))
out = model(batch)

print("Pred shape:", out.shape)
print("Target shape:", batch.y.shape)
print("Loss:", nn.MSELoss()(out, batch.y).item())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_55/3285922516.py in <cell line: 0>()
#       1 batch = next(iter(train_loader))
# ----> 2 out = model(batch)
#       3
#       4 print("Pred shape:", out.shape)
#       5 print("Target shape:", batch.y.shape)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /tmp/ipykernel_55/297626224.py in forward(self, data)
#      65     def forward(self, data):
#      66
# ---> 67         x = self.embedding(data.x)
#      68         pos = data.pos
#      69
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     132         Runs the forward pass.
#     133         """
# --> 134         return F.linear(input, self.weight, self.bias)
#     135
#     136     def extra_repr(self) -> str:
#
# RuntimeError: Expected all tensors to be on the same device, but got mat1 is on cpu, different from other tensors on cuda:0 (when checking argument in method wrapper_CUDA_addmm)

# %% [markdown]
# # Training Setup

# %%
import torch
import torch.nn as nn

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = RNAEGNN(
    in_channels=train_graphs[0].x.size(1),
    hidden_dim=128,
    layers=3
).to(device)

optimizer = torch.optim.Adam(
    model.parameters(),
    lr=5e-4,
    weight_decay=1e-5
)

criterion = nn.MSELoss()

# %% [markdown]
# Device Check

# %%
batch = next(iter(train_loader)).to(device)
out = model(batch)

print("Model device:", next(model.parameters()).device)
print("Batch device:", batch.x.device)
print("Output device:", out.device)
# Out:
# Model device: cuda:0
# Batch device: cuda:0
# Output device: cuda:0

# %% [markdown]
# Shape Check

# %%
print("Pred shape:", out.shape)
print("Target shape:", batch.y.shape)
# Out:
# Pred shape: torch.Size([3200, 3])
# Target shape: torch.Size([3200, 3])

# %% [markdown]
# Finite Values Check

# %%
print("Any NaN in output?", torch.isnan(out).any().item())
print("Any Inf in output?", torch.isinf(out).any().item())
# Out:
# Any NaN in output? False
# Any Inf in output? False

# %% [markdown]
# Loss Scale Check

# %%
loss = criterion(out, batch.y)
print("Initial loss:", loss.item())
# Out:
# Initial loss: 0.0005018849042244256

# %% [markdown]
# Coordinate Magnitude Stability

# %%
print("Target std:", batch.y.std().item())
print("Pred std:", out.std().item())
# Out:
# Target std: 0.9218757748603821
# Pred std: 0.9189948439598083

# %% [markdown]
# One Training Step Check

# %%
optimizer.zero_grad()
loss.backward()

torch.nn.utils.clip_grad_norm_(model.parameters(), 5.0)

optimizer.step()

print("Post-step loss:",
      criterion(model(batch), batch.y).item())
# Out:
# Post-step loss: 0.01888907514512539

# %%
print("Max difference:",
      (out - batch.pos).abs().max().item())
# Out:
# Max difference: 0.4301303029060364

# %% [markdown]
# # Metrics

# %%
def compute_rmsd(pred, target):
    return torch.sqrt(torch.mean(torch.sum((pred - target)**2, dim=1)))

# %% [markdown]
# # train and Validate

# %%
def train():
    model.train()
    total_loss = 0

    for batch in train_loader:
        batch = batch.to(device)

        optimizer.zero_grad()
        pred = model(batch)

        loss = criterion(pred, batch.y)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss / len(train_loader)


def evaluate():
    model.eval()
    total_loss = 0
    total_rmsd = 0

    with torch.no_grad():
        for batch in val_loader:
            batch = batch.to(device)

            pred = model(batch)
            loss = criterion(pred, batch.y)
            rmsd = compute_rmsd(pred, batch.y)

            total_loss += loss.item()
            total_rmsd += rmsd.item()

    return total_loss / len(val_loader), total_rmsd / len(val_loader)

# %% [markdown]
# # Training Loop

# %%
for epoch in range(20):
    train_loss = train()
    val_loss, val_rmsd = evaluate()

    print(f"Epoch {epoch+1:02d} | "
          f"Train Loss: {train_loss:.4f} | "
          f"Val Loss: {val_loss:.4f} | "
          f"Val RMSD: {val_rmsd:.4f}")

# %% [markdown]
# # Test Inference

# %%
model.eval()
predictions = {}

with torch.no_grad():
    for sid, x, _ in test_dataset:
        graph = build_graph(x, coords=None)
        graph = graph.to(device)

        # For test, we cannot predict coords yet (no pos)
        # Need trained decoder head for inference.
        # Placeholder here.

        predictions[sid] = None
